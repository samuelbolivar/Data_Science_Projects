# %%
# %matplotlib inline
# Out:
# /Users/samuelbolivar/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import pandas

# %%
import pandas as pd

# %%
s = pd.Series([1.2, 0.1, 1.8, 0.3], index=["am hi", "am lo", "pm hi", "pm lo"])

# %%
s.plot()

# %%
import matplotlib.pyplot

# %%
s
# Out:
# am hi    1.2
# am lo    0.1
# pm hi    1.8
# pm lo    0.3
# dtype: float64

# %%
matplotlib.pyplot.xlabel("Time of tide")

# %%
s.plot()
matplotlib.pyplot.xlabel("Time of tide")
matplotlib.pyplot.ylabel("metres")

# %%
s.plot?

# %%
s.plot(logx=True, logy=True)

# %%
all_trains = pd.read_csv('../SYD_DAT_5/data/sydtrains.csv', throusands=',', index_col=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-73efe48aff4d> in <module>()
# ----> 1 all_trains = pd.read_csv('../SYD_DAT_5/data/sydtrains.csv', throusands=',', index_col=1)
#
# TypeError: parser_f() got an unexpected keyword argument 'throusands'
